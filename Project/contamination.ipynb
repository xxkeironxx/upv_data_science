# %%
import pandas as pd
import xlrd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

c1=pd.read_csv('1.csv',encoding = "ISO-8859-1", sep=";")
c3=pd.read_csv('3A.csv',encoding = "ISO-8859-1", sep=";")
c4=pd.read_csv('4A.csv',encoding = "ISO-8859-1", sep=";")
c5=pd.read_csv('5A.csv',encoding = "ISO-8859-1", sep=";")
c6=pd.read_csv('6A.csv',encoding = "ISO-8859-1", sep=";")
c7=pd.read_csv('7A.csv',encoding = "ISO-8859-1", sep=";")

c1=c1[['Fecha','Ozono(µg/m³)','NO(µg/m³)', 'NO2(µg/m³)', 'PM10(µg/m³)', 'NOx(µg/m³)', 'SO2(µg/m³)']]
c3=c3[['Fecha','Ozono(µg/m³)','NO(µg/m³)', 'NO2(µg/m³)', 'PM10(µg/m³)', 'NOx(µg/m³)', 'SO2(µg/m³)']]
c4=c4[['Fecha','Ozono(µg/m³)','NO(µg/m³)', 'NO2(µg/m³)', 'PM10(µg/m³)', 'NOx(µg/m³)', 'SO2(µg/m³)' ]]
c5=c5[['Fecha','Ozono(µg/m³)','NO(µg/m³)', 'NO2(µg/m³)', 'PM10(µg/m³)', 'NOx(µg/m³)', 'SO2(µg/m³)' ]]
c6=c6[['Fecha','Ozono(µg/m³)','NO(µg/m³)', 'NO2(µg/m³)', 'PM10(µg/m³)', 'NOx(µg/m³)', 'SO2(µg/m³)' ]]
c7=c7[['Fecha','Ozono(µg/m³)','NO(µg/m³)', 'NO2(µg/m³)', 'PM10(µg/m³)', 'NOx(µg/m³)', 'SO2(µg/m³)' ]]
#adding column with "month/year" value
c1['month']=pd.to_datetime(c1["Fecha"],format="%d/%m/%Y").dt.strftime("%m/%y")
c3['month']=pd.to_datetime(c3["Fecha"],format="%d/%m/%Y").dt.strftime("%m/%y")
c4['month']=pd.to_datetime(c4["Fecha"],format="%d/%m/%Y").dt.strftime("%m/%y")
c5['Fecha']=pd.to_datetime(c5["Fecha"],format="%d.%m.%Y").dt.strftime("%d/%m/%Y")
c5['month']=pd.to_datetime(c5["Fecha"],format="%d/%m/%Y").dt.strftime("%m/%y")
c6['month']=pd.to_datetime(c6["Fecha"],format="%d/%m/%Y").dt.strftime("%m/%y")
c7['month']=pd.to_datetime(c7["Fecha"],format="%d/%m/%Y").dt.strftime("%m/%y")

#replacing the date column with "period/year"
#.replace(['01','02','12'], 'winter', regex = True).replace(['03','04','05'], 'spring', regex = True).replace(['06','07','08'], 'summer', regex = True).replace(['09','10','11'], 'autumn', regex = True)
#c1['month']=c1['month'].str.replace(r"01", "winter")

c1_p=c1.copy()
c1_p['month']=c1_p['month'].replace(['01','02','12'], 'winter', regex = True).replace(['03','04','05'], 'spring', regex = True).replace(['06','07','08'], 'summer', regex = True).replace(['09','10','11'], 'autumn', regex = True)
c3_p=c3.copy()
c3_p['month']=c3_p['month'].replace(['01','02','12'], 'winter', regex = True).replace(['03','04','05'], 'spring', regex = True).replace(['06','07','08'], 'summer', regex = True).replace(['09','10','11'], 'autumn', regex = True)
c4_p=c4.copy()
c4_p['month']=c4_p['month'].replace(['01','02','12'], 'winter', regex = True).replace(['03','04','05'], 'spring', regex = True).replace(['06','07','08'], 'summer', regex = True).replace(['09','10','11'], 'autumn', regex = True)
c5_p=c5.copy()
c5_p['month']=c5_p['month'].replace(['01','02','12'], 'winter', regex = True).replace(['03','04','05'], 'spring', regex = True).replace(['06','07','08'], 'summer', regex = True).replace(['09','10','11'], 'autumn', regex = True)
c6_p=c6.copy()
c6_p['month']=c6_p['month'].replace(['01','02','12'], 'winter', regex = True).replace(['03','04','05'], 'spring', regex = True).replace(['06','07','08'], 'summer', regex = True).replace(['09','10','11'], 'autumn', regex = True)
c7_p=c7.copy()
c7_p['month']=c7_p['month'].replace(['01','02','12'], 'winter', regex = True).replace(['03','04','05'], 'spring', regex = True).replace(['06','07','08'], 'summer', regex = True).replace(['09','10','11'], 'autumn', regex = True)
#group and calclulate mean
c1_g=c1_p.groupby("month").mean().reset_index()
c3_g=c3_p.groupby("month").mean().reset_index()
c4_g=c4_p.groupby("month").mean().reset_index()
c5_g=c5_p.groupby("month").mean().reset_index()
c6_g=c6_p.groupby("month").mean().reset_index()
c7_g=c7_p.groupby("month").mean().reset_index()


c1_aut=c1_g[c1_g['month'].str.contains("autumn")]
c1_aut['year']=c1_aut['month'].replace('.*/', '', regex = True)
c1_spr=c1_g[c1_g['month'].str.contains("spring")]
c1_spr['year']=c1_spr['month'].replace('.*/', '', regex = True)
c1_sum=c1_g[c1_g['month'].str.contains("summer")]
c1_sum['year']=c1_sum['month'].replace('.*/', '', regex = True)
c1_win=c1_g[c1_g['month'].str.contains("winter")]
c1_win['year']=c1_win['month'].replace('.*/', '', regex = True)

##subplot winter
plt.subplot(2, 2, 1)
plt.plot(c1_win['year'], c1_win["Ozono(µg/m³)"], label='Ozono')
plt.plot(c1_win['year'], c1_win["NO(µg/m³)"], label='NO')
plt.plot(c1_win['year'], c1_win["NO2(µg/m³)"], label='NO2')
plt.plot(c1_win['year'], c1_win["PM10(µg/m³)"], label='PM10')
plt.plot(c1_win['year'], c1_win["NOx(µg/m³)"], label='NOx')
plt.plot(c1_win['year'], c1_win["SO2(µg/m³)"], label='SO2')
#plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.title('c1_winter') 
plt.xlabel('year')
plt.ylabel('contamination, µg/m³')
#subplot spring
plt.subplot(2, 2, 2)
plt.plot(c1_spr['year'], c1_spr["Ozono(µg/m³)"], label='Ozono')
plt.plot(c1_spr['year'], c1_spr["NO(µg/m³)"], label='NO')
plt.plot(c1_spr['year'], c1_spr["NO2(µg/m³)"], label='NO2')
plt.plot(c1_spr['year'], c1_spr["PM10(µg/m³)"], label='PM10')
plt.plot(c1_spr['year'], c1_spr["NOx(µg/m³)"], label='NOx')
plt.plot(c1_spr['year'], c1_spr["SO2(µg/m³)"], label='SO2')
lgd=plt.legend(bbox_to_anchor=(1.05, 0.1), loc=2, borderaxespad=0.)
plt.title('c1_spring') 
plt.xlabel('year')
plt.ylabel('contamination, µg/m³')
###subplot summer
plt.subplot(2, 2, 3)
plt.plot(c1_sum['year'], c1_sum["Ozono(µg/m³)"], label='Ozono')
plt.plot(c1_sum['year'], c1_sum["NO(µg/m³)"], label='NO')
plt.plot(c1_sum['year'], c1_sum["NO2(µg/m³)"], label='NO2')
plt.plot(c1_sum['year'], c1_sum["PM10(µg/m³)"], label='PM10')
plt.plot(c1_sum['year'], c1_sum["NOx(µg/m³)"], label='NOx')
plt.plot(c1_sum['year'], c1_sum["SO2(µg/m³)"], label='SO2')
#plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.title('c1_summer') 
plt.xlabel('year')
plt.ylabel('contamination, µg/m³')
#subplot autumn
plt.subplot(2, 2, 4)
plt.plot(c1_aut['year'], c1_aut["Ozono(µg/m³)"], label='Ozono')
plt.plot(c1_aut['year'], c1_aut["NO(µg/m³)"], label='NO')
plt.plot(c1_aut['year'], c1_aut["NO2(µg/m³)"], label='NO2')
plt.plot(c1_aut['year'], c1_aut["PM10(µg/m³)"], label='PM10')
plt.plot(c1_aut['year'], c1_aut["NOx(µg/m³)"], label='NOx')
plt.plot(c1_aut['year'], c1_aut["SO2(µg/m³)"], label='SO2')
#plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.title('c1_autumn') 
plt.xlabel('year')
plt.ylabel('contamination, µg/m³')
plt.tight_layout()
plt.savefig('c1.png',dpi=100,bbox_extra_artists=(lgd,), bbox_inches='tight')
plt.show()


#c1_g
####plt.subplot(1, 1, 1)

#c1_aut
#c5
#Fecha 	PM2.5(µg/m³) 	PM1(µg/m³) 	SO2(µg/m³) 	NO(µg/m³) 	NO2(µg/m³) 	PM10(µg/m³) 	NOx(µg/m³) 	Ozono(µg/m³)
#Fecha 	PM2.5(µg/m³) 	PM1(µg/m³) 	SO2(µg/m³) 	CO(mg/m³) 	NO(µg/m³) 	NO2(µg/m³) 	PM10(µg/m³) 	NOx(µg/m³) 	Ozono(µg/m³)
#Fecha 	PM2,5(µg/m³) 	PM1(µg/m³) 	Xileno(µg/m³) 	SO2(µg/m³) 	CO(mg/m³) 	NO(µg/m³) 	NO2(µg/m³) 	PM10(µg/m³) 	NOx(µg/m³) 	Ozono(µg/m³) 	Tolueno(µg/m³) 	Benceno(µg/m³) 	Ruido(dBA)
#Fecha 	PM2.5(µg/m³) 	SO2(µg/m³) 	NO(µg/m³) 	NO2(µg/m³) 	PM10(µg/m³) 	Ni(ng/m³) 	NOx(µg/m³) 	Ozono(µg/m³) 	As(ng/m³) 	Pb(µg/m³) 	Cd(ng/m³)
#Fecha 	PM2,5(µg/m³) 	SO2(µg/m³) 	CO(mg/m³) 	NO(µg/m³) 	NO2(µg/m³) 	PM10(µg/m³) 	NOx(µg/m³) 	Ozono(µg/m³) 	Veloc.(m/s)
#Fecha 	SO2(µg/m³) 	NO(µg/m³) 	NO2(µg/m³) 	PM10(µg/m³) 	Ni(ng/m³) 	NOx(µg/m³) 	Ozono(µg/m³) 	As(ng/m³) 	Pb(µg/m³) 	BaP(ng/m³) 	Cd(ng/m³)
#ozono, No, NO2, PM10, NOx

c1_g
# Out:
#         month  Ozono(µg/m³)  NO(µg/m³)  NO2(µg/m³)  PM10(µg/m³)  NOx(µg/m³)  \
# 0   autumn/14     45.263158   9.703297   33.318681    18.769231   47.615385
# 1   autumn/15     48.800000  11.318681   38.175824    16.523256   54.472527
# 2   autumn/16     40.428571   5.511628   21.953488    13.659341   30.453488
# 3   spring/14     66.152174   4.627907   23.697674    17.108696   30.837209
# 4   spring/15     71.858696   5.875000   24.738636    16.260870   32.761364
# 5   spring/16     63.456522   3.746032   18.206349    13.619565   22.285714
# 6   spring/17     62.943820   4.258824   23.247059    10.967033   29.529412
# 7   summer/14     63.758242   2.692308   16.758242    20.250000   20.714286
# 8   summer/15     70.527473   3.066667   16.722222    18.565217   20.177778
# 9   summer/16     59.677778   1.766667   11.844444    15.722892   14.544444
# 10  summer/17     56.706522   2.554348   15.369565     7.673913   19.119565
# ...

# %%
import pandas as pd
import xlrd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

c1=pd.read_csv('1.csv',encoding = "ISO-8859-1", sep=";")
c3=pd.read_csv('3A.csv',encoding = "ISO-8859-1", sep=";")
c4=pd.read_csv('4A.csv',encoding = "ISO-8859-1", sep=";")
c5=pd.read_csv('5A.csv',encoding = "ISO-8859-1", sep=";")
c6=pd.read_csv('6A.csv',encoding = "ISO-8859-1", sep=";")
c7=pd.read_csv('7A.csv',encoding = "ISO-8859-1", sep=";")

c1=c1[['Fecha','Ozono(µg/m³)','NO(µg/m³)', 'NO2(µg/m³)', 'PM10(µg/m³)', 'NOx(µg/m³)', 'SO2(µg/m³)']]
c3=c3[['Fecha','Ozono(µg/m³)','NO(µg/m³)', 'NO2(µg/m³)', 'PM10(µg/m³)', 'NOx(µg/m³)', 'SO2(µg/m³)']]
c4=c4[['Fecha','Ozono(µg/m³)','NO(µg/m³)', 'NO2(µg/m³)', 'PM10(µg/m³)', 'NOx(µg/m³)', 'SO2(µg/m³)' ]]
c5=c5[['Fecha','Ozono(µg/m³)','NO(µg/m³)', 'NO2(µg/m³)', 'PM10(µg/m³)', 'NOx(µg/m³)', 'SO2(µg/m³)' ]]
c6=c6[['Fecha','Ozono(µg/m³)','NO(µg/m³)', 'NO2(µg/m³)', 'PM10(µg/m³)', 'NOx(µg/m³)', 'SO2(µg/m³)' ]]
c7=c7[['Fecha','Ozono(µg/m³)','NO(µg/m³)', 'NO2(µg/m³)', 'PM10(µg/m³)', 'NOx(µg/m³)', 'SO2(µg/m³)' ]]
#adding column with "month/year" value
c1['month']=pd.to_datetime(c1["Fecha"],format="%d/%m/%Y").dt.strftime("%m/%y")
c3['month']=pd.to_datetime(c3["Fecha"],format="%d/%m/%Y").dt.strftime("%m/%y")
c4['month']=pd.to_datetime(c4["Fecha"],format="%d/%m/%Y").dt.strftime("%m/%y")
c5['Fecha']=pd.to_datetime(c5["Fecha"],format="%d.%m.%Y").dt.strftime("%d/%m/%Y")
c5['month']=pd.to_datetime(c5["Fecha"],format="%d/%m/%Y").dt.strftime("%m/%y")
c6['month']=pd.to_datetime(c6["Fecha"],format="%d/%m/%Y").dt.strftime("%m/%y")
c7['month']=pd.to_datetime(c7["Fecha"],format="%d/%m/%Y").dt.strftime("%m/%y")

#replacing the date column with "period/year"
#.replace(['01','02','12'], 'winter', regex = True).replace(['03','04','05'], 'spring', regex = True).replace(['06','07','08'], 'summer', regex = True).replace(['09','10','11'], 'autumn', regex = True)
#c1['month']=c1['month'].str.replace(r"01", "winter")

c1_p=c1.copy()
c1_p['month']=c1_p['month'].replace(['01','02','12'], 'winter', regex = True).replace(['03','04','05'], 'spring', regex = True).replace(['06','07','08'], 'summer', regex = True).replace(['09','10','11'], 'autumn', regex = True)
c3_p=c3.copy()
c3_p['month']=c3_p['month'].replace(['01','02','12'], 'winter', regex = True).replace(['03','04','05'], 'spring', regex = True).replace(['06','07','08'], 'summer', regex = True).replace(['09','10','11'], 'autumn', regex = True)
c4_p=c4.copy()
c4_p['month']=c4_p['month'].replace(['01','02','12'], 'winter', regex = True).replace(['03','04','05'], 'spring', regex = True).replace(['06','07','08'], 'summer', regex = True).replace(['09','10','11'], 'autumn', regex = True)
c5_p=c5.copy()
c5_p['month']=c5_p['month'].replace(['01','02','12'], 'winter', regex = True).replace(['03','04','05'], 'spring', regex = True).replace(['06','07','08'], 'summer', regex = True).replace(['09','10','11'], 'autumn', regex = True)
c6_p=c6.copy()
c6_p['month']=c6_p['month'].replace(['01','02','12'], 'winter', regex = True).replace(['03','04','05'], 'spring', regex = True).replace(['06','07','08'], 'summer', regex = True).replace(['09','10','11'], 'autumn', regex = True)
c7_p=c7.copy()
c7_p['month']=c7_p['month'].replace(['01','02','12'], 'winter', regex = True).replace(['03','04','05'], 'spring', regex = True).replace(['06','07','08'], 'summer', regex = True).replace(['09','10','11'], 'autumn', regex = True)
#group and calclulate mean
#c1_g=c1_p.groupby("month").median().reset_index()
c1_g=c3_p.groupby("month").mean().reset_index()
c4_g=c4_p.groupby("month").mean().reset_index()
c5_g=c5_p.groupby("month").mean().reset_index()
c6_g=c6_p.groupby("month").mean().reset_index()
c7_g=c7_p.groupby("month").mean().reset_index()


c1_aut=c1_g[c1_g['month'].str.contains("autumn")]
c1_aut['year']=c1_aut['month'].replace('.*/', '', regex = True)
c1_spr=c1_g[c1_g['month'].str.contains("spring")]
c1_spr['year']=c1_spr['month'].replace('.*/', '', regex = True)
c1_sum=c1_g[c1_g['month'].str.contains("summer")]
c1_sum['year']=c1_sum['month'].replace('.*/', '', regex = True)
c1_win=c1_g[c1_g['month'].str.contains("winter")]
c1_win['year']=c1_win['month'].replace('.*/', '', regex = True)

##subplot winter
plt.subplot(2, 2, 1)
plt.plot(c1_win['year'], c1_win["Ozono(µg/m³)"], label='Ozono')
plt.plot(c1_win['year'], c1_win["NO(µg/m³)"], label='NO')
plt.plot(c1_win['year'], c1_win["NO2(µg/m³)"], label='NO2')
plt.plot(c1_win['year'], c1_win["PM10(µg/m³)"], label='PM10')
plt.plot(c1_win['year'], c1_win["NOx(µg/m³)"], label='NOx')
plt.plot(c1_win['year'], c1_win["SO2(µg/m³)"], label='SO2')
#plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.title('c3_winter') 
plt.xlabel('year')
plt.ylabel('contamination, µg/m³')
#subplot spring
plt.subplot(2, 2, 2)
plt.plot(c1_spr['year'], c1_spr["Ozono(µg/m³)"], label='Ozono')
plt.plot(c1_spr['year'], c1_spr["NO(µg/m³)"], label='NO')
plt.plot(c1_spr['year'], c1_spr["NO2(µg/m³)"], label='NO2')
plt.plot(c1_spr['year'], c1_spr["PM10(µg/m³)"], label='PM10')
plt.plot(c1_spr['year'], c1_spr["NOx(µg/m³)"], label='NOx')
plt.plot(c1_spr['year'], c1_spr["SO2(µg/m³)"], label='SO2')
lgd=plt.legend(bbox_to_anchor=(1.05, 0.1), loc=2, borderaxespad=0.)
plt.title('c3_spring') 
plt.xlabel('year')
plt.ylabel('contamination, µg/m³')
###subplot summer
plt.subplot(2, 2, 3)
plt.plot(c1_sum['year'], c1_sum["Ozono(µg/m³)"], label='Ozono')
plt.plot(c1_sum['year'], c1_sum["NO(µg/m³)"], label='NO')
plt.plot(c1_sum['year'], c1_sum["NO2(µg/m³)"], label='NO2')
plt.plot(c1_sum['year'], c1_sum["PM10(µg/m³)"], label='PM10')
plt.plot(c1_sum['year'], c1_sum["NOx(µg/m³)"], label='NOx')
plt.plot(c1_sum['year'], c1_sum["SO2(µg/m³)"], label='SO2')
#plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.title('c3_summer') 
plt.xlabel('year')
plt.ylabel('contamination, µg/m³')
#subplot autumn
plt.subplot(2, 2, 4)
plt.plot(c1_aut['year'], c1_aut["Ozono(µg/m³)"], label='Ozono')
plt.plot(c1_aut['year'], c1_aut["NO(µg/m³)"], label='NO')
plt.plot(c1_aut['year'], c1_aut["NO2(µg/m³)"], label='NO2')
plt.plot(c1_aut['year'], c1_aut["PM10(µg/m³)"], label='PM10')
plt.plot(c1_aut['year'], c1_aut["NOx(µg/m³)"], label='NOx')
plt.plot(c1_aut['year'], c1_aut["SO2(µg/m³)"], label='SO2')
#plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.title('c3_autumn') 
plt.xlabel('year')
plt.ylabel('contamination, µg/m³')
plt.tight_layout()
plt.savefig('c3.png',dpi=100,bbox_extra_artists=(lgd,), bbox_inches='tight')
plt.show()
####plt.subplot(1, 1, 1)

# %%
import pandas as pd
import xlrd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

c1=pd.read_csv('1.csv',encoding = "ISO-8859-1", sep=";")
c3=pd.read_csv('3A.csv',encoding = "ISO-8859-1", sep=";")
c4=pd.read_csv('4A.csv',encoding = "ISO-8859-1", sep=";")
c5=pd.read_csv('5A.csv',encoding = "ISO-8859-1", sep=";")
c6=pd.read_csv('6A.csv',encoding = "ISO-8859-1", sep=";")
c7=pd.read_csv('7A.csv',encoding = "ISO-8859-1", sep=";")

c1=c1[['Fecha','Ozono(µg/m³)','NO(µg/m³)', 'NO2(µg/m³)', 'PM10(µg/m³)', 'NOx(µg/m³)', 'SO2(µg/m³)']]
c3=c3[['Fecha','Ozono(µg/m³)','NO(µg/m³)', 'NO2(µg/m³)', 'PM10(µg/m³)', 'NOx(µg/m³)', 'SO2(µg/m³)']]
c4=c4[['Fecha','Ozono(µg/m³)','NO(µg/m³)', 'NO2(µg/m³)', 'PM10(µg/m³)', 'NOx(µg/m³)', 'SO2(µg/m³)' ]]
c5=c5[['Fecha','Ozono(µg/m³)','NO(µg/m³)', 'NO2(µg/m³)', 'PM10(µg/m³)', 'NOx(µg/m³)', 'SO2(µg/m³)' ]]
c6=c6[['Fecha','Ozono(µg/m³)','NO(µg/m³)', 'NO2(µg/m³)', 'PM10(µg/m³)', 'NOx(µg/m³)', 'SO2(µg/m³)' ]]
c7=c7[['Fecha','Ozono(µg/m³)','NO(µg/m³)', 'NO2(µg/m³)', 'PM10(µg/m³)', 'NOx(µg/m³)', 'SO2(µg/m³)' ]]
#adding column with "month/year" value
c1['month']=pd.to_datetime(c1["Fecha"],format="%d/%m/%Y").dt.strftime("%m/%y")
c3['month']=pd.to_datetime(c3["Fecha"],format="%d/%m/%Y").dt.strftime("%m/%y")
c4['month']=pd.to_datetime(c4["Fecha"],format="%d/%m/%Y").dt.strftime("%m/%y")
c5['Fecha']=pd.to_datetime(c5["Fecha"],format="%d.%m.%Y").dt.strftime("%d/%m/%Y")
c5['month']=pd.to_datetime(c5["Fecha"],format="%d/%m/%Y").dt.strftime("%m/%y")
c6['month']=pd.to_datetime(c6["Fecha"],format="%d/%m/%Y").dt.strftime("%m/%y")
c7['month']=pd.to_datetime(c7["Fecha"],format="%d/%m/%Y").dt.strftime("%m/%y")

#replacing the date column with "period/year"
#.replace(['01','02','12'], 'winter', regex = True).replace(['03','04','05'], 'spring', regex = True).replace(['06','07','08'], 'summer', regex = True).replace(['09','10','11'], 'autumn', regex = True)
#c1['month']=c1['month'].str.replace(r"01", "winter")

c1_p=c1.copy()
c1_p['month']=c1_p['month'].replace(['01','02','12'], 'winter', regex = True).replace(['03','04','05'], 'spring', regex = True).replace(['06','07','08'], 'summer', regex = True).replace(['09','10','11'], 'autumn', regex = True)
c3_p=c3.copy()
c3_p['month']=c3_p['month'].replace(['01','02','12'], 'winter', regex = True).replace(['03','04','05'], 'spring', regex = True).replace(['06','07','08'], 'summer', regex = True).replace(['09','10','11'], 'autumn', regex = True)
c4_p=c4.copy()
c4_p['month']=c4_p['month'].replace(['01','02','12'], 'winter', regex = True).replace(['03','04','05'], 'spring', regex = True).replace(['06','07','08'], 'summer', regex = True).replace(['09','10','11'], 'autumn', regex = True)
c5_p=c5.copy()
c5_p['month']=c5_p['month'].replace(['01','02','12'], 'winter', regex = True).replace(['03','04','05'], 'spring', regex = True).replace(['06','07','08'], 'summer', regex = True).replace(['09','10','11'], 'autumn', regex = True)
c6_p=c6.copy()
c6_p['month']=c6_p['month'].replace(['01','02','12'], 'winter', regex = True).replace(['03','04','05'], 'spring', regex = True).replace(['06','07','08'], 'summer', regex = True).replace(['09','10','11'], 'autumn', regex = True)
c7_p=c7.copy()
c7_p['month']=c7_p['month'].replace(['01','02','12'], 'winter', regex = True).replace(['03','04','05'], 'spring', regex = True).replace(['06','07','08'], 'summer', regex = True).replace(['09','10','11'], 'autumn', regex = True)
#group and calclulate mean
#c1_g=c1_p.groupby("month").mean().reset_index()
#c3_g=c3_p.groupby("month").mean().reset_index()
c1_g=c4_p.groupby("month").mean().reset_index()
c5_g=c5_p.groupby("month").mean().reset_index()
c6_g=c6_p.groupby("month").mean().reset_index()
c7_g=c7_p.groupby("month").mean().reset_index()


c1_aut=c1_g[c1_g['month'].str.contains("autumn")]
c1_aut['year']=c1_aut['month'].replace('.*/', '', regex = True)
c1_spr=c1_g[c1_g['month'].str.contains("spring")]
c1_spr['year']=c1_spr['month'].replace('.*/', '', regex = True)
c1_sum=c1_g[c1_g['month'].str.contains("summer")]
c1_sum['year']=c1_sum['month'].replace('.*/', '', regex = True)
c1_win=c1_g[c1_g['month'].str.contains("winter")]
c1_win['year']=c1_win['month'].replace('.*/', '', regex = True)

##subplot winter
plt.subplot(2, 2, 1)
plt.plot(c1_win['year'], c1_win["Ozono(µg/m³)"], label='Ozono')
plt.plot(c1_win['year'], c1_win["NO(µg/m³)"], label='NO')
plt.plot(c1_win['year'], c1_win["NO2(µg/m³)"], label='NO2')
plt.plot(c1_win['year'], c1_win["PM10(µg/m³)"], label='PM10')
plt.plot(c1_win['year'], c1_win["NOx(µg/m³)"], label='NOx')
plt.plot(c1_win['year'], c1_win["SO2(µg/m³)"], label='SO2')
#plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.title('c4_winter') 
plt.xlabel('year')
plt.ylabel('contamination, µg/m³')
#subplot spring
plt.subplot(2, 2, 2)
plt.plot(c1_spr['year'], c1_spr["Ozono(µg/m³)"], label='Ozono')
plt.plot(c1_spr['year'], c1_spr["NO(µg/m³)"], label='NO')
plt.plot(c1_spr['year'], c1_spr["NO2(µg/m³)"], label='NO2')
plt.plot(c1_spr['year'], c1_spr["PM10(µg/m³)"], label='PM10')
plt.plot(c1_spr['year'], c1_spr["NOx(µg/m³)"], label='NOx')
plt.plot(c1_spr['year'], c1_spr["SO2(µg/m³)"], label='SO2')
lgd=plt.legend(bbox_to_anchor=(1.05, 0.1), loc=2, borderaxespad=0.)
plt.title('c4_spring') 
plt.xlabel('year')
plt.ylabel('contamination, µg/m³')
###subplot summer
plt.subplot(2, 2, 3)
plt.plot(c1_sum['year'], c1_sum["Ozono(µg/m³)"], label='Ozono')
plt.plot(c1_sum['year'], c1_sum["NO(µg/m³)"], label='NO')
plt.plot(c1_sum['year'], c1_sum["NO2(µg/m³)"], label='NO2')
plt.plot(c1_sum['year'], c1_sum["PM10(µg/m³)"], label='PM10')
plt.plot(c1_sum['year'], c1_sum["NOx(µg/m³)"], label='NOx')
plt.plot(c1_sum['year'], c1_sum["SO2(µg/m³)"], label='SO2')
#plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.title('c4_summer') 
plt.xlabel('year')
plt.ylabel('contamination, µg/m³')
#subplot autumn
plt.subplot(2, 2, 4)
plt.plot(c1_aut['year'], c1_aut["Ozono(µg/m³)"], label='Ozono')
plt.plot(c1_aut['year'], c1_aut["NO(µg/m³)"], label='NO')
plt.plot(c1_aut['year'], c1_aut["NO2(µg/m³)"], label='NO2')
plt.plot(c1_aut['year'], c1_aut["PM10(µg/m³)"], label='PM10')
plt.plot(c1_aut['year'], c1_aut["NOx(µg/m³)"], label='NOx')
plt.plot(c1_aut['year'], c1_aut["SO2(µg/m³)"], label='SO2')
#plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.title('c4_autumn') 
plt.xlabel('year')
plt.ylabel('contamination, µg/m³')
plt.tight_layout()
plt.savefig('c4.png',dpi=100,bbox_extra_artists=(lgd,), bbox_inches='tight')
plt.show()

####plt.subplot(1, 1, 1)

# %%
import pandas as pd
import xlrd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

c1=pd.read_csv('1.csv',encoding = "ISO-8859-1", sep=";")
c3=pd.read_csv('3A.csv',encoding = "ISO-8859-1", sep=";")
c4=pd.read_csv('4A.csv',encoding = "ISO-8859-1", sep=";")
c5=pd.read_csv('5A.csv',encoding = "ISO-8859-1", sep=";")
c6=pd.read_csv('6A.csv',encoding = "ISO-8859-1", sep=";")
c7=pd.read_csv('7A.csv',encoding = "ISO-8859-1", sep=";")

c1=c1[['Fecha','Ozono(µg/m³)','NO(µg/m³)', 'NO2(µg/m³)', 'PM10(µg/m³)', 'NOx(µg/m³)', 'SO2(µg/m³)']]
c3=c3[['Fecha','Ozono(µg/m³)','NO(µg/m³)', 'NO2(µg/m³)', 'PM10(µg/m³)', 'NOx(µg/m³)', 'SO2(µg/m³)']]
c4=c4[['Fecha','Ozono(µg/m³)','NO(µg/m³)', 'NO2(µg/m³)', 'PM10(µg/m³)', 'NOx(µg/m³)', 'SO2(µg/m³)' ]]
c5=c5[['Fecha','Ozono(µg/m³)','NO(µg/m³)', 'NO2(µg/m³)', 'PM10(µg/m³)', 'NOx(µg/m³)', 'SO2(µg/m³)' ]]
c6=c6[['Fecha','Ozono(µg/m³)','NO(µg/m³)', 'NO2(µg/m³)', 'PM10(µg/m³)', 'NOx(µg/m³)', 'SO2(µg/m³)' ]]
c7=c7[['Fecha','Ozono(µg/m³)','NO(µg/m³)', 'NO2(µg/m³)', 'PM10(µg/m³)', 'NOx(µg/m³)', 'SO2(µg/m³)' ]]
#adding column with "month/year" value
c1['month']=pd.to_datetime(c1["Fecha"],format="%d/%m/%Y").dt.strftime("%m/%y")
c3['month']=pd.to_datetime(c3["Fecha"],format="%d/%m/%Y").dt.strftime("%m/%y")
c4['month']=pd.to_datetime(c4["Fecha"],format="%d/%m/%Y").dt.strftime("%m/%y")
c5['Fecha']=pd.to_datetime(c5["Fecha"],format="%d.%m.%Y").dt.strftime("%d/%m/%Y")
c5['month']=pd.to_datetime(c5["Fecha"],format="%d/%m/%Y").dt.strftime("%m/%y")
c6['month']=pd.to_datetime(c6["Fecha"],format="%d/%m/%Y").dt.strftime("%m/%y")
c7['month']=pd.to_datetime(c7["Fecha"],format="%d/%m/%Y").dt.strftime("%m/%y")

#replacing the date column with "period/year"
#.replace(['01','02','12'], 'winter', regex = True).replace(['03','04','05'], 'spring', regex = True).replace(['06','07','08'], 'summer', regex = True).replace(['09','10','11'], 'autumn', regex = True)
#c1['month']=c1['month'].str.replace(r"01", "winter")

c1_p=c1.copy()
c1_p['month']=c1_p['month'].replace(['01','02','12'], 'winter', regex = True).replace(['03','04','05'], 'spring', regex = True).replace(['06','07','08'], 'summer', regex = True).replace(['09','10','11'], 'autumn', regex = True)
c3_p=c3.copy()
c3_p['month']=c3_p['month'].replace(['01','02','12'], 'winter', regex = True).replace(['03','04','05'], 'spring', regex = True).replace(['06','07','08'], 'summer', regex = True).replace(['09','10','11'], 'autumn', regex = True)
c4_p=c4.copy()
c4_p['month']=c4_p['month'].replace(['01','02','12'], 'winter', regex = True).replace(['03','04','05'], 'spring', regex = True).replace(['06','07','08'], 'summer', regex = True).replace(['09','10','11'], 'autumn', regex = True)
c5_p=c5.copy()
c5_p['month']=c5_p['month'].replace(['01','02','12'], 'winter', regex = True).replace(['03','04','05'], 'spring', regex = True).replace(['06','07','08'], 'summer', regex = True).replace(['09','10','11'], 'autumn', regex = True)
c6_p=c6.copy()
c6_p['month']=c6_p['month'].replace(['01','02','12'], 'winter', regex = True).replace(['03','04','05'], 'spring', regex = True).replace(['06','07','08'], 'summer', regex = True).replace(['09','10','11'], 'autumn', regex = True)
c7_p=c7.copy()
c7_p['month']=c7_p['month'].replace(['01','02','12'], 'winter', regex = True).replace(['03','04','05'], 'spring', regex = True).replace(['06','07','08'], 'summer', regex = True).replace(['09','10','11'], 'autumn', regex = True)
#group and calclulate mean
#c1_g=c1_p.groupby("month").mean().reset_index()
#c3_g=c3_p.groupby("month").mean().reset_index()
#c4_g=c4_p.groupby("month").mean().reset_index()
c1_g=c5_p.groupby("month").mean().reset_index()
c6_g=c6_p.groupby("month").mean().reset_index()
c7_g=c7_p.groupby("month").mean().reset_index()


c1_aut=c1_g[c1_g['month'].str.contains("autumn")]
c1_aut['year']=c1_aut['month'].replace('.*/', '', regex = True)
c1_spr=c1_g[c1_g['month'].str.contains("spring")]
c1_spr['year']=c1_spr['month'].replace('.*/', '', regex = True)
c1_sum=c1_g[c1_g['month'].str.contains("summer")]
c1_sum['year']=c1_sum['month'].replace('.*/', '', regex = True)
c1_win=c1_g[c1_g['month'].str.contains("winter")]
c1_win['year']=c1_win['month'].replace('.*/', '', regex = True)

##subplot winter
plt.subplot(2, 2, 1)
plt.plot(c1_win['year'], c1_win["Ozono(µg/m³)"], label='Ozono')
plt.plot(c1_win['year'], c1_win["NO(µg/m³)"], label='NO')
plt.plot(c1_win['year'], c1_win["NO2(µg/m³)"], label='NO2')
plt.plot(c1_win['year'], c1_win["PM10(µg/m³)"], label='PM10')
plt.plot(c1_win['year'], c1_win["NOx(µg/m³)"], label='NOx')
plt.plot(c1_win['year'], c1_win["SO2(µg/m³)"], label='SO2')
#plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.title('c5_winter') 
plt.xlabel('year')
plt.ylabel('contamination, µg/m³')
#subplot spring
plt.subplot(2, 2, 2)
plt.plot(c1_spr['year'], c1_spr["Ozono(µg/m³)"], label='Ozono')
plt.plot(c1_spr['year'], c1_spr["NO(µg/m³)"], label='NO')
plt.plot(c1_spr['year'], c1_spr["NO2(µg/m³)"], label='NO2')
plt.plot(c1_spr['year'], c1_spr["PM10(µg/m³)"], label='PM10')
plt.plot(c1_spr['year'], c1_spr["NOx(µg/m³)"], label='NOx')
plt.plot(c1_spr['year'], c1_spr["SO2(µg/m³)"], label='SO2')
lgd=plt.legend(bbox_to_anchor=(1.05, 0.1), loc=2, borderaxespad=0.)
plt.title('c5_spring') 
plt.xlabel('year')
plt.ylabel('contamination, µg/m³')
###subplot summer
plt.subplot(2, 2, 3)
plt.plot(c1_sum['year'], c1_sum["Ozono(µg/m³)"], label='Ozono')
plt.plot(c1_sum['year'], c1_sum["NO(µg/m³)"], label='NO')
plt.plot(c1_sum['year'], c1_sum["NO2(µg/m³)"], label='NO2')
plt.plot(c1_sum['year'], c1_sum["PM10(µg/m³)"], label='PM10')
plt.plot(c1_sum['year'], c1_sum["NOx(µg/m³)"], label='NOx')
plt.plot(c1_sum['year'], c1_sum["SO2(µg/m³)"], label='SO2')
#plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.title('c5_summer') 
plt.xlabel('year')
plt.ylabel('contamination, µg/m³')
#subplot autumn
plt.subplot(2, 2, 4)
plt.plot(c1_aut['year'], c1_aut["Ozono(µg/m³)"], label='Ozono')
plt.plot(c1_aut['year'], c1_aut["NO(µg/m³)"], label='NO')
plt.plot(c1_aut['year'], c1_aut["NO2(µg/m³)"], label='NO2')
plt.plot(c1_aut['year'], c1_aut["PM10(µg/m³)"], label='PM10')
plt.plot(c1_aut['year'], c1_aut["NOx(µg/m³)"], label='NOx')
plt.plot(c1_aut['year'], c1_aut["SO2(µg/m³)"], label='SO2')
#plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.title('c5_autumn') 
plt.xlabel('year')
plt.ylabel('contamination, µg/m³')
plt.tight_layout()
plt.savefig('c5.png',dpi=100,bbox_extra_artists=(lgd,), bbox_inches='tight')
plt.show()

####plt.subplot(1, 1, 1)

# %%
import pandas as pd
import xlrd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

c1=pd.read_csv('1.csv',encoding = "ISO-8859-1", sep=";")
c3=pd.read_csv('3A.csv',encoding = "ISO-8859-1", sep=";")
c4=pd.read_csv('4A.csv',encoding = "ISO-8859-1", sep=";")
c5=pd.read_csv('5A.csv',encoding = "ISO-8859-1", sep=";")
c6=pd.read_csv('6A.csv',encoding = "ISO-8859-1", sep=";")
c7=pd.read_csv('7A.csv',encoding = "ISO-8859-1", sep=";")

c1=c1[['Fecha','Ozono(µg/m³)','NO(µg/m³)', 'NO2(µg/m³)', 'PM10(µg/m³)', 'NOx(µg/m³)', 'SO2(µg/m³)']]
c3=c3[['Fecha','Ozono(µg/m³)','NO(µg/m³)', 'NO2(µg/m³)', 'PM10(µg/m³)', 'NOx(µg/m³)', 'SO2(µg/m³)']]
c4=c4[['Fecha','Ozono(µg/m³)','NO(µg/m³)', 'NO2(µg/m³)', 'PM10(µg/m³)', 'NOx(µg/m³)', 'SO2(µg/m³)' ]]
c5=c5[['Fecha','Ozono(µg/m³)','NO(µg/m³)', 'NO2(µg/m³)', 'PM10(µg/m³)', 'NOx(µg/m³)', 'SO2(µg/m³)' ]]
c6=c6[['Fecha','Ozono(µg/m³)','NO(µg/m³)', 'NO2(µg/m³)', 'PM10(µg/m³)', 'NOx(µg/m³)', 'SO2(µg/m³)' ]]
c7=c7[['Fecha','Ozono(µg/m³)','NO(µg/m³)', 'NO2(µg/m³)', 'PM10(µg/m³)', 'NOx(µg/m³)', 'SO2(µg/m³)' ]]
#adding column with "month/year" value
c1['month']=pd.to_datetime(c1["Fecha"],format="%d/%m/%Y").dt.strftime("%m/%y")
c3['month']=pd.to_datetime(c3["Fecha"],format="%d/%m/%Y").dt.strftime("%m/%y")
c4['month']=pd.to_datetime(c4["Fecha"],format="%d/%m/%Y").dt.strftime("%m/%y")
c5['Fecha']=pd.to_datetime(c5["Fecha"],format="%d.%m.%Y").dt.strftime("%d/%m/%Y")
c5['month']=pd.to_datetime(c5["Fecha"],format="%d/%m/%Y").dt.strftime("%m/%y")
c6['month']=pd.to_datetime(c6["Fecha"],format="%d/%m/%Y").dt.strftime("%m/%y")
c7['month']=pd.to_datetime(c7["Fecha"],format="%d/%m/%Y").dt.strftime("%m/%y")

#replacing the date column with "period/year"
#.replace(['01','02','12'], 'winter', regex = True).replace(['03','04','05'], 'spring', regex = True).replace(['06','07','08'], 'summer', regex = True).replace(['09','10','11'], 'autumn', regex = True)
#c1['month']=c1['month'].str.replace(r"01", "winter")

c1_p=c1.copy()
c1_p['month']=c1_p['month'].replace(['01','02','12'], 'winter', regex = True).replace(['03','04','05'], 'spring', regex = True).replace(['06','07','08'], 'summer', regex = True).replace(['09','10','11'], 'autumn', regex = True)
c3_p=c3.copy()
c3_p['month']=c3_p['month'].replace(['01','02','12'], 'winter', regex = True).replace(['03','04','05'], 'spring', regex = True).replace(['06','07','08'], 'summer', regex = True).replace(['09','10','11'], 'autumn', regex = True)
c4_p=c4.copy()
c4_p['month']=c4_p['month'].replace(['01','02','12'], 'winter', regex = True).replace(['03','04','05'], 'spring', regex = True).replace(['06','07','08'], 'summer', regex = True).replace(['09','10','11'], 'autumn', regex = True)
c5_p=c5.copy()
c5_p['month']=c5_p['month'].replace(['01','02','12'], 'winter', regex = True).replace(['03','04','05'], 'spring', regex = True).replace(['06','07','08'], 'summer', regex = True).replace(['09','10','11'], 'autumn', regex = True)
c6_p=c6.copy()
c6_p['month']=c6_p['month'].replace(['01','02','12'], 'winter', regex = True).replace(['03','04','05'], 'spring', regex = True).replace(['06','07','08'], 'summer', regex = True).replace(['09','10','11'], 'autumn', regex = True)
c7_p=c7.copy()
c7_p['month']=c7_p['month'].replace(['01','02','12'], 'winter', regex = True).replace(['03','04','05'], 'spring', regex = True).replace(['06','07','08'], 'summer', regex = True).replace(['09','10','11'], 'autumn', regex = True)
#group and calclulate mean
#c1_g=c1_p.groupby("month").mean().reset_index()
#c3_g=c3_p.groupby("month").mean().reset_index()
#c4_g=c4_p.groupby("month").mean().reset_index()
#c5_g=c5_p.groupby("month").mean().reset_index()
c1_g=c6_p.groupby("month").mean().reset_index()
#c7_g=c7_p.groupby("month").mean().reset_index()


c1_aut=c1_g[c1_g['month'].str.contains("autumn")]
c1_aut['year']=c1_aut['month'].replace('.*/', '', regex = True)
c1_spr=c1_g[c1_g['month'].str.contains("spring")]
c1_spr['year']=c1_spr['month'].replace('.*/', '', regex = True)
c1_sum=c1_g[c1_g['month'].str.contains("summer")]
c1_sum['year']=c1_sum['month'].replace('.*/', '', regex = True)
c1_win=c1_g[c1_g['month'].str.contains("winter")]
c1_win['year']=c1_win['month'].replace('.*/', '', regex = True)

##subplot winter
plt.subplot(2, 2, 1)
plt.plot(c1_win['year'], c1_win["Ozono(µg/m³)"], label='Ozono')
plt.plot(c1_win['year'], c1_win["NO(µg/m³)"], label='NO')
plt.plot(c1_win['year'], c1_win["NO2(µg/m³)"], label='NO2')
plt.plot(c1_win['year'], c1_win["PM10(µg/m³)"], label='PM10')
plt.plot(c1_win['year'], c1_win["NOx(µg/m³)"], label='NOx')
plt.plot(c1_win['year'], c1_win["SO2(µg/m³)"], label='SO2')
#plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.title('c6_winter') 
plt.xlabel('year')
plt.ylabel('contamination, µg/m³')
#subplot spring
plt.subplot(2, 2, 2)
plt.plot(c1_spr['year'], c1_spr["Ozono(µg/m³)"], label='Ozono')
plt.plot(c1_spr['year'], c1_spr["NO(µg/m³)"], label='NO')
plt.plot(c1_spr['year'], c1_spr["NO2(µg/m³)"], label='NO2')
plt.plot(c1_spr['year'], c1_spr["PM10(µg/m³)"], label='PM10')
plt.plot(c1_spr['year'], c1_spr["NOx(µg/m³)"], label='NOx')
plt.plot(c1_spr['year'], c1_spr["SO2(µg/m³)"], label='SO2')
lgd=plt.legend(bbox_to_anchor=(1.05, 0.1), loc=2, borderaxespad=0.)
plt.title('c6_spring') 
plt.xlabel('year')
plt.ylabel('contamination, µg/m³')
###subplot summer
plt.subplot(2, 2, 3)
plt.plot(c1_sum['year'], c1_sum["Ozono(µg/m³)"], label='Ozono')
plt.plot(c1_sum['year'], c1_sum["NO(µg/m³)"], label='NO')
plt.plot(c1_sum['year'], c1_sum["NO2(µg/m³)"], label='NO2')
plt.plot(c1_sum['year'], c1_sum["PM10(µg/m³)"], label='PM10')
plt.plot(c1_sum['year'], c1_sum["NOx(µg/m³)"], label='NOx')
plt.plot(c1_sum['year'], c1_sum["SO2(µg/m³)"], label='SO2')
#plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.title('c6_summer') 
plt.xlabel('year')
plt.ylabel('contamination, µg/m³')
#subplot autumn
plt.subplot(2, 2, 4)
plt.plot(c1_aut['year'], c1_aut["Ozono(µg/m³)"], label='Ozono')
plt.plot(c1_aut['year'], c1_aut["NO(µg/m³)"], label='NO')
plt.plot(c1_aut['year'], c1_aut["NO2(µg/m³)"], label='NO2')
plt.plot(c1_aut['year'], c1_aut["PM10(µg/m³)"], label='PM10')
plt.plot(c1_aut['year'], c1_aut["NOx(µg/m³)"], label='NOx')
plt.plot(c1_aut['year'], c1_aut["SO2(µg/m³)"], label='SO2')
#plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.title('c6_autumn') 
plt.xlabel('year')
plt.ylabel('contamination, µg/m³')
plt.tight_layout()
plt.savefig('c6.png',dpi=100,bbox_extra_artists=(lgd,), bbox_inches='tight')
plt.show()


#print(c6_p[c6_p['month'].str.contains("summer/17")])
####plt.subplot(1, 1, 1)

# %%
import pandas as pd
import xlrd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

c1=pd.read_csv('1.csv',encoding = "ISO-8859-1", sep=";")
c3=pd.read_csv('3A.csv',encoding = "ISO-8859-1", sep=";")
c4=pd.read_csv('4A.csv',encoding = "ISO-8859-1", sep=";")
c5=pd.read_csv('5A.csv',encoding = "ISO-8859-1", sep=";")
c6=pd.read_csv('6A.csv',encoding = "ISO-8859-1", sep=";")
c7=pd.read_csv('7A.csv',encoding = "ISO-8859-1", sep=";")

c1=c1[['Fecha','Ozono(µg/m³)','NO(µg/m³)', 'NO2(µg/m³)', 'PM10(µg/m³)', 'NOx(µg/m³)', 'SO2(µg/m³)']]
c3=c3[['Fecha','Ozono(µg/m³)','NO(µg/m³)', 'NO2(µg/m³)', 'PM10(µg/m³)', 'NOx(µg/m³)', 'SO2(µg/m³)']]
c4=c4[['Fecha','Ozono(µg/m³)','NO(µg/m³)', 'NO2(µg/m³)', 'PM10(µg/m³)', 'NOx(µg/m³)', 'SO2(µg/m³)' ]]
c5=c5[['Fecha','Ozono(µg/m³)','NO(µg/m³)', 'NO2(µg/m³)', 'PM10(µg/m³)', 'NOx(µg/m³)', 'SO2(µg/m³)' ]]
c6=c6[['Fecha','Ozono(µg/m³)','NO(µg/m³)', 'NO2(µg/m³)', 'PM10(µg/m³)', 'NOx(µg/m³)', 'SO2(µg/m³)' ]]
c7=c7[['Fecha','Ozono(µg/m³)','NO(µg/m³)', 'NO2(µg/m³)', 'PM10(µg/m³)', 'NOx(µg/m³)', 'SO2(µg/m³)' ]]
#adding column with "month/year" value
c1['month']=pd.to_datetime(c1["Fecha"],format="%d/%m/%Y").dt.strftime("%m/%y")
c3['month']=pd.to_datetime(c3["Fecha"],format="%d/%m/%Y").dt.strftime("%m/%y")
c4['month']=pd.to_datetime(c4["Fecha"],format="%d/%m/%Y").dt.strftime("%m/%y")
c5['Fecha']=pd.to_datetime(c5["Fecha"],format="%d.%m.%Y").dt.strftime("%d/%m/%Y")
c5['month']=pd.to_datetime(c5["Fecha"],format="%d/%m/%Y").dt.strftime("%m/%y")
c6['month']=pd.to_datetime(c6["Fecha"],format="%d/%m/%Y").dt.strftime("%m/%y")
c7['month']=pd.to_datetime(c7["Fecha"],format="%d/%m/%Y").dt.strftime("%m/%y")

#replacing the date column with "period/year"
#.replace(['01','02','12'], 'winter', regex = True).replace(['03','04','05'], 'spring', regex = True).replace(['06','07','08'], 'summer', regex = True).replace(['09','10','11'], 'autumn', regex = True)
#c1['month']=c1['month'].str.replace(r"01", "winter")

c1_p=c1.copy()
c1_p['month']=c1_p['month'].replace(['01','02','12'], 'winter', regex = True).replace(['03','04','05'], 'spring', regex = True).replace(['06','07','08'], 'summer', regex = True).replace(['09','10','11'], 'autumn', regex = True)
c3_p=c3.copy()
c3_p['month']=c3_p['month'].replace(['01','02','12'], 'winter', regex = True).replace(['03','04','05'], 'spring', regex = True).replace(['06','07','08'], 'summer', regex = True).replace(['09','10','11'], 'autumn', regex = True)
c4_p=c4.copy()
c4_p['month']=c4_p['month'].replace(['01','02','12'], 'winter', regex = True).replace(['03','04','05'], 'spring', regex = True).replace(['06','07','08'], 'summer', regex = True).replace(['09','10','11'], 'autumn', regex = True)
c5_p=c5.copy()
c5_p['month']=c5_p['month'].replace(['01','02','12'], 'winter', regex = True).replace(['03','04','05'], 'spring', regex = True).replace(['06','07','08'], 'summer', regex = True).replace(['09','10','11'], 'autumn', regex = True)
c6_p=c6.copy()
c6_p['month']=c6_p['month'].replace(['01','02','12'], 'winter', regex = True).replace(['03','04','05'], 'spring', regex = True).replace(['06','07','08'], 'summer', regex = True).replace(['09','10','11'], 'autumn', regex = True)
c7_p=c7.copy()
c7_p['month']=c7_p['month'].replace(['01','02','12'], 'winter', regex = True).replace(['03','04','05'], 'spring', regex = True).replace(['06','07','08'], 'summer', regex = True).replace(['09','10','11'], 'autumn', regex = True)
#group and calclulate mean
#c1_g=c1_p.groupby("month").mean().reset_index()
#c3_g=c3_p.groupby("month").mean().reset_index()
#c4_g=c4_p.groupby("month").mean().reset_index()
#c5_g=c5_p.groupby("month").mean().reset_index()
#c6_g=c6_p.groupby("month").mean().reset_index()
c1_g=c7_p.groupby("month").mean().reset_index()


c1_aut=c1_g[c1_g['month'].str.contains("autumn")]
c1_aut['year']=c1_aut['month'].replace('.*/', '', regex = True)
c1_spr=c1_g[c1_g['month'].str.contains("spring")]
c1_spr['year']=c1_spr['month'].replace('.*/', '', regex = True)
c1_sum=c1_g[c1_g['month'].str.contains("summer")]
c1_sum['year']=c1_sum['month'].replace('.*/', '', regex = True)
c1_win=c1_g[c1_g['month'].str.contains("winter")]
c1_win['year']=c1_win['month'].replace('.*/', '', regex = True)

##subplot winter
plt.subplot(2, 2, 1)
plt.plot(c1_win['year'], c1_win["Ozono(µg/m³)"], label='Ozono')
plt.plot(c1_win['year'], c1_win["NO(µg/m³)"], label='NO')
plt.plot(c1_win['year'], c1_win["NO2(µg/m³)"], label='NO2')
plt.plot(c1_win['year'], c1_win["PM10(µg/m³)"], label='PM10')
plt.plot(c1_win['year'], c1_win["NOx(µg/m³)"], label='NOx')
plt.plot(c1_win['year'], c1_win["SO2(µg/m³)"], label='SO2')
#plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.title('c7_winter') 
plt.xlabel('year')
plt.ylabel('contamination, µg/m³')
#subplot spring
plt.subplot(2, 2, 2)
plt.plot(c1_spr['year'], c1_spr["Ozono(µg/m³)"], label='Ozono')
plt.plot(c1_spr['year'], c1_spr["NO(µg/m³)"], label='NO')
plt.plot(c1_spr['year'], c1_spr["NO2(µg/m³)"], label='NO2')
plt.plot(c1_spr['year'], c1_spr["PM10(µg/m³)"], label='PM10')
plt.plot(c1_spr['year'], c1_spr["NOx(µg/m³)"], label='NOx')
plt.plot(c1_spr['year'], c1_spr["SO2(µg/m³)"], label='SO2')
lgd=plt.legend(bbox_to_anchor=(1.05, 0.1), loc=2, borderaxespad=0.)
plt.title('c7_spring') 
plt.xlabel('year')
plt.ylabel('contamination, µg/m³')
###subplot summer
plt.subplot(2, 2, 3)
plt.plot(c1_sum['year'], c1_sum["Ozono(µg/m³)"], label='Ozono')
plt.plot(c1_sum['year'], c1_sum["NO(µg/m³)"], label='NO')
plt.plot(c1_sum['year'], c1_sum["NO2(µg/m³)"], label='NO2')
plt.plot(c1_sum['year'], c1_sum["PM10(µg/m³)"], label='PM10')
plt.plot(c1_sum['year'], c1_sum["NOx(µg/m³)"], label='NOx')
plt.plot(c1_sum['year'], c1_sum["SO2(µg/m³)"], label='SO2')
#plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.title('c7_summer') 
plt.xlabel('year')
plt.ylabel('contamination, µg/m³')
#subplot autumn
plt.subplot(2, 2, 4)
plt.plot(c1_aut['year'], c1_aut["Ozono(µg/m³)"], label='Ozono')
plt.plot(c1_aut['year'], c1_aut["NO(µg/m³)"], label='NO')
plt.plot(c1_aut['year'], c1_aut["NO2(µg/m³)"], label='NO2')
plt.plot(c1_aut['year'], c1_aut["PM10(µg/m³)"], label='PM10')
plt.plot(c1_aut['year'], c1_aut["NOx(µg/m³)"], label='NOx')
plt.plot(c1_aut['year'], c1_aut["SO2(µg/m³)"], label='SO2')
#plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.title('c7_autumn') 
plt.xlabel('year')
plt.ylabel('contamination, µg/m³')
plt.tight_layout()
plt.savefig('c7.png',dpi=100,bbox_extra_artists=(lgd,), bbox_inches='tight')
plt.show()

####plt.subplot(1, 1, 1)

# %%
import pandas as pd
import xlrd
import matplotlib.pyplot as plt
import warnings
import numpy as np
warnings.filterwarnings("ignore")

c1=pd.read_csv('1.csv',encoding = "ISO-8859-1", sep=";")
c3=pd.read_csv('3A.csv',encoding = "ISO-8859-1", sep=";")
c4=pd.read_csv('4A.csv',encoding = "ISO-8859-1", sep=";")
c5=pd.read_csv('5A.csv',encoding = "ISO-8859-1", sep=";")
c6=pd.read_csv('6A.csv',encoding = "ISO-8859-1", sep=";")
c7=pd.read_csv('7A.csv',encoding = "ISO-8859-1", sep=";")



c1=c1[['Fecha','Ozono(µg/m³)','NO(µg/m³)', 'NO2(µg/m³)', 'PM10(µg/m³)', 'NOx(µg/m³)', 'SO2(µg/m³)']]
c3=c3[['Fecha','Ozono(µg/m³)','NO(µg/m³)', 'NO2(µg/m³)', 'PM10(µg/m³)', 'NOx(µg/m³)', 'SO2(µg/m³)']]
c4=c4[['Fecha','Ozono(µg/m³)','NO(µg/m³)', 'NO2(µg/m³)', 'PM10(µg/m³)', 'NOx(µg/m³)', 'SO2(µg/m³)' ]]
c5=c5[['Fecha','Ozono(µg/m³)','NO(µg/m³)', 'NO2(µg/m³)', 'PM10(µg/m³)', 'NOx(µg/m³)', 'SO2(µg/m³)' ]]
c6=c6[['Fecha','Ozono(µg/m³)','NO(µg/m³)', 'NO2(µg/m³)', 'PM10(µg/m³)', 'NOx(µg/m³)', 'SO2(µg/m³)' ]]
c7=c7[['Fecha','Ozono(µg/m³)','NO(µg/m³)', 'NO2(µg/m³)', 'PM10(µg/m³)', 'NOx(µg/m³)', 'SO2(µg/m³)' ]]
c5['Fecha']=pd.to_datetime(c5["Fecha"],format="%d.%m.%Y").dt.strftime("%d/%m/%Y")

#grep 2016 year
c1_y=c1[c1["Fecha"].str.contains("/2016")==True]
c3_y=c3[c3["Fecha"].str.contains("/2016")==True]
c4_y=c4[c4["Fecha"].str.contains("/2016")==True]
c5_y=c5[c5["Fecha"].str.contains("/2016")==True]
c6_y=c6[c6["Fecha"].str.contains("/2016")==True]
c7_y=c7[c7["Fecha"].str.contains("/2016")==True]

c1_ym=c1_y.mean(axis=0)
c1_ym=pd.DataFrame({'Cont':c1_ym.index, 'mean':c1_ym.values})
c3_ym=c3_y.mean(axis=0)
c3_ym=pd.DataFrame({'Cont':c3_ym.index, 'mean':c3_ym.values})
c4_ym=c4_y.mean(axis=0)
c4_ym=pd.DataFrame({'Cont':c4_ym.index, 'mean':c4_ym.values})
c5_ym=c5_y.mean(axis=0)
c5_ym=pd.DataFrame({'Cont':c5_ym.index, 'mean':c5_ym.values})
c6_ym=c6_y.mean(axis=0)
c6_ym=pd.DataFrame({'Cont':c6_ym.index, 'mean':c6_ym.values})
c7_ym=c7_y.mean(axis=0)
c7_ym=pd.DataFrame({'Cont':c7_ym.index, 'mean':c7_ym.values})



#PLOTPART
N = 6 #amount of groups(contamination types)
ind = np.arange(1,N+1)  # the x locations for the groups
width = 0.14
multiple_bars = plt.figure()
ax = plt.subplot(111)
r1=ax.bar(ind, c1_ym['mean'],width,color='b',align='center')
r3=ax.bar(ind+width, c3_ym['mean'],width,color='g',align='center')
r4=ax.bar(ind+width*2, c4_ym['mean'],width,color='purple',align='center')
r5=ax.bar(ind+width*3, c5_ym['mean'],width,color='brown',align='center')
r6=ax.bar(ind+width*4, c6_ym['mean'],width,color='orange',align='center')
r7=ax.bar(ind+width*5, c7_ym['mean'],width,color='gray',align='center')

ax.set_xticks(ind+width*2)
ax.set_xticklabels( c1_ym["Cont"],size='smaller' )

def autolabel(rects):
    for rect in rects:
        h = rect.get_height()
        if np.isnan(h):
            h=0
        ax.text(rect.get_x()+rect.get_width()/2., 1.05*h, '%d'%int(h),
                ha='center', va='bottom',size='smaller')
        
lgd=ax.legend( (r1[0], r3[0], r4[0],r5[0],r6[0],r7[0]), ('c1','c3','c4','c5','c6','c7'),bbox_to_anchor=(1.01, 1), loc=2, borderaxespad=0. )
autolabel(r1)
autolabel(r3)
autolabel(r4)
autolabel(r5)
autolabel(r6)
autolabel(r7)
plt.title('average contamination in 2016') 
plt.xlabel('contamination type')
plt.ylabel('contamination, µg/m³')
plt.ylim([0,90])
plt.tight_layout()


plt.savefig('average 2016.png',dpi=100,bbox_extra_artists=(lgd,), bbox_inches='tight')
plt.show()


result=pd.concat([c1_ym, c3_ym['mean'], c4_ym['mean'], c5_ym['mean'], c6_ym['mean'], c7_ym['mean']], axis=1)
result.columns.values[1] = 'c1'
result.columns.values[2] = 'c3'
result.columns.values[3] = 'c4'
result.columns.values[4] = 'c5'
result.columns.values[5] = 'c6'
result.columns.values[6] = 'c7'
result.to_csv('average2016.csv',sep=";")
result
# Out:
#            Cont         c1         c3         c4         c5         c6  \
# 0  Ozono(µg/m³)  51.250000  49.918033  41.684211  50.799451  46.296407
# 1     NO(µg/m³)   5.433846   9.079268  24.413793   7.681159  11.284404
# 2    NO2(µg/m³)  20.726154  22.823171  42.511494  22.880435  32.073394
# 3   PM10(µg/m³)  14.559322  14.854342  23.058496  24.260870        NaN
# 4    NOx(µg/m³)  28.523077  36.250000  79.704023  34.253623  48.611621
# 5    SO2(µg/m³)   3.147632   3.259563   3.704545   3.172881   3.602339
#
#           c7
# 0  47.868347
# 1  13.690962
# 2  31.425656
# 3  21.691667
# 4  52.195335
# 5   3.648094

# %%
import pandas as pd
import xlrd
import matplotlib.pyplot as plt
import matplotlib.dates as dt
import warnings
import numpy as np
import datetime
import scipy.ndimage.filters
import scipy.interpolate
from scipy.interpolate import interp1d
#warnings.filterwarnings("ignore")

c1=pd.read_csv('1.csv',encoding = "ISO-8859-1", sep=";")
c1=c1[['Fecha','Ozono(µg/m³)','NO(µg/m³)', 'NO2(µg/m³)', 'PM10(µg/m³)', 'NOx(µg/m³)', 'SO2(µg/m³)']]
#c1=c1[c1["Fecha"].str.contains("/2016")==True]
c1['Fecha']=pd.to_datetime(c1["Fecha"],format="%d/%m/%Y")
dates = [dt.date2num(t) for t in c1['Fecha']]
values=c1["Ozono(µg/m³)"]

#gauss
#filtered = scipy.ndimage.filters.gaussian_filter1d(c1["Ozono(µg/m³)"], sigma=2)
#plt.plot(c1['Fecha'], filtered, label='Ozono')
#plt.show()


#####Ozone
f = interp1d(dates, values)
xnew = np.linspace(dates[0], dates[-1], num=200, endpoint=True)

#plt.subplot(2, 1, 1)

plt.plot(dt.num2date(xnew), f(xnew), label='Ozono')
plt.gcf().autofmt_xdate()
plt.title('Ozono_spline') 
plt.xlabel('date')
plt.ylabel('contamination, µg/m³')
plt.tight_layout()
plt.savefig('c1_Ozono_spline.png',dpi=100)
plt.show()

plt.plot(dt.num2date(dates),c1["Ozono(µg/m³)"] , label='Ozono')
plt.gcf().autofmt_xdate()
plt.title('Ozono_raw') 
plt.xlabel('date')
plt.ylabel('contamination, µg/m³')
plt.tight_layout()
plt.savefig('c1_Ozono_raw.png',dpi=100)
plt.show()

###########NO
values=c1["NO(µg/m³)"]
f = interp1d(dates, values)
plt.plot(dt.num2date(xnew), f(xnew), label='NO')
plt.gcf().autofmt_xdate()
plt.title('NO_spline') 
plt.xlabel('date')
plt.ylabel('contamination, µg/m³')
plt.tight_layout()
plt.savefig('c1_NO_spline.png',dpi=100)
plt.show()

plt.plot(dt.num2date(dates),c1["NO(µg/m³)"] , label='NO')
plt.gcf().autofmt_xdate()
plt.title('NO_raw') 
plt.xlabel('date')
plt.ylabel('contamination, µg/m³')
plt.tight_layout()
plt.savefig('c1_NO_raw.png',dpi=100)
plt.show()


########NO2
values=c1["NO2(µg/m³)"]
f = interp1d(dates, values)
plt.plot(dt.num2date(xnew), f(xnew), label='NO2')
plt.gcf().autofmt_xdate()
plt.title('NO2_spline') 
plt.xlabel('date')
plt.ylabel('contamination, µg/m³')
plt.tight_layout()
plt.savefig('c1_NO2_spline.png',dpi=100)
plt.show()

plt.plot(dt.num2date(dates),c1["NO2(µg/m³)"] , label='NO2')
plt.gcf().autofmt_xdate()
plt.title('NO2_raw') 
plt.xlabel('date')
plt.ylabel('contamination, µg/m³')
plt.tight_layout()
plt.savefig('c1_NO2_raw.png',dpi=100)
plt.show()


###########PM10
values=c1["PM10(µg/m³)"]
f = interp1d(dates, values)
plt.plot(dt.num2date(xnew), f(xnew), label='PM10')
plt.gcf().autofmt_xdate()
plt.title('PM10_spline') 
plt.xlabel('date')
plt.ylabel('contamination, µg/m³')
plt.tight_layout()
plt.savefig('c1_PM10_spline.png',dpi=100)
plt.show()

plt.plot(dt.num2date(dates),c1["PM10(µg/m³)"] , label='PM10')
plt.gcf().autofmt_xdate()
plt.title('PM10_raw') 
plt.xlabel('date')
plt.ylabel('contamination, µg/m³')
plt.tight_layout()
plt.savefig('c1_PM10_raw.png',dpi=100)
plt.show()


##########NOx
values=c1["NOx(µg/m³)"]
f = interp1d(dates, values)
plt.plot(dt.num2date(xnew), f(xnew), label='NOx')
plt.gcf().autofmt_xdate()
plt.title('NOx_spline') 
plt.xlabel('date')
plt.ylabel('contamination, µg/m³')
plt.tight_layout()
plt.savefig('c1_NOx_spline.png',dpi=100)
plt.show()

plt.plot(dt.num2date(dates),c1["NOx(µg/m³)"] , label='NOx')
plt.gcf().autofmt_xdate()
plt.title('NOx_raw') 
plt.xlabel('date')
plt.ylabel('contamination, µg/m³')
plt.tight_layout()
plt.savefig('c1_NOx_raw.png',dpi=100)
plt.show()

######SO2
values=c1['SO2(µg/m³)']
f = interp1d(dates, values)
plt.plot(dt.num2date(xnew), f(xnew), label='SO2')
plt.gcf().autofmt_xdate()
plt.title('SO2_spline') 
plt.xlabel('date')
plt.ylabel('contamination, µg/m³')
plt.tight_layout()
plt.savefig('c1_SO2_spline.png',dpi=100)
plt.show()

plt.plot(dt.num2date(dates),c1['SO2(µg/m³)'] , label='SO2')
plt.gcf().autofmt_xdate()
plt.title('SO2_raw') 
plt.xlabel('date')
plt.ylabel('contamination, µg/m³')
plt.tight_layout()
plt.savefig('c1_SO2_raw.png',dpi=100)
plt.show()
#pfilter_line.set_data(x,filtered)lt.plot(c1['Fecha'], c1["Ozono(µg/m³)"], label='Ozono')
#plt.plot(c1['Fecha'], c1["Ozono(µg/m³)"], label='NO')
#plt.plot(c1['Fecha'], c1["NO(µg/m³)"], label='NO')
#plt.plot(c1['Fecha'], c1["NO2(µg/m³)"], label='NO2')
#plt.plot(c1['Fecha'], c1["PM10(µg/m³)"], label='PM10')
#plt.plot(c1['Fecha'], c1["NOx(µg/m³)"], label='NOx')
#plt.savefig('c1_total.png',dpi=100)

# %%
import pandas as pd
import xlrd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

c1=pd.read_csv('1.csv',encoding = "ISO-8859-1", sep=";")
c3=pd.read_csv('3A.csv',encoding = "ISO-8859-1", sep=";")
c4=pd.read_csv('4A.csv',encoding = "ISO-8859-1", sep=";")
c5=pd.read_csv('5A.csv',encoding = "ISO-8859-1", sep=";")
c6=pd.read_csv('6A.csv',encoding = "ISO-8859-1", sep=";")
c7=pd.read_csv('7A.csv',encoding = "ISO-8859-1", sep=";")

c1=c1[['Fecha','Ozono(µg/m³)','NO(µg/m³)', 'NO2(µg/m³)', 'PM10(µg/m³)', 'NOx(µg/m³)', 'SO2(µg/m³)']]
c3=c3[['Fecha','Ozono(µg/m³)','NO(µg/m³)', 'NO2(µg/m³)', 'PM10(µg/m³)', 'NOx(µg/m³)', 'SO2(µg/m³)']]
c4=c4[['Fecha','Ozono(µg/m³)','NO(µg/m³)', 'NO2(µg/m³)', 'PM10(µg/m³)', 'NOx(µg/m³)', 'SO2(µg/m³)' ]]
c5=c5[['Fecha','Ozono(µg/m³)','NO(µg/m³)', 'NO2(µg/m³)', 'PM10(µg/m³)', 'NOx(µg/m³)', 'SO2(µg/m³)' ]]
c6=c6[['Fecha','Ozono(µg/m³)','NO(µg/m³)', 'NO2(µg/m³)', 'PM10(µg/m³)', 'NOx(µg/m³)', 'SO2(µg/m³)' ]]
c7=c7[['Fecha','Ozono(µg/m³)','NO(µg/m³)', 'NO2(µg/m³)', 'PM10(µg/m³)', 'NOx(µg/m³)', 'SO2(µg/m³)' ]]
#adding column with "month/year" value
c1['month']=pd.to_datetime(c1["Fecha"],format="%d/%m/%Y").dt.strftime("%m/%y")
c3['month']=pd.to_datetime(c3["Fecha"],format="%d/%m/%Y").dt.strftime("%m/%y")
c4['month']=pd.to_datetime(c4["Fecha"],format="%d/%m/%Y").dt.strftime("%m/%y")
c5['Fecha']=pd.to_datetime(c5["Fecha"],format="%d.%m.%Y").dt.strftime("%d/%m/%Y")
c5['month']=pd.to_datetime(c5["Fecha"],format="%d/%m/%Y").dt.strftime("%m/%y")
c6['month']=pd.to_datetime(c6["Fecha"],format="%d/%m/%Y").dt.strftime("%m/%y")
c7['month']=pd.to_datetime(c7["Fecha"],format="%d/%m/%Y").dt.strftime("%m/%y")


c1_p=c1.copy()

#group and calclulate mean
c1_g=c1.groupby("month").mean().reset_index()
c3_g=c3.groupby("month").mean().reset_index()
c4_g=c4.groupby("month").mean().reset_index()
c5_g=c5.groupby("month").mean().reset_index()
c6_g=c6.groupby("month").mean().reset_index()
c7_g=c7.groupby("month").mean().reset_index()



c1_g.to_csv('c1_average_month.csv',sep=";")
c3_g.to_csv('c3_average_month.csv',sep=";")
c4_g.to_csv('c4_average_month.csv',sep=";")
c5_g.to_csv('c5_average_month.csv',sep=";")
c6_g.to_csv('c6_average_month.csv',sep=";")
c7_g.to_csv('c7_average_month.csv',sep=";")
#c3_g
#br=c6[c6["month"].str.match("../16")]
#np.isnan(br['PM10(µg/m³)']).describe()
# Out:
# count      358
# unique       1
# top       True
# freq       358
# Name: PM10(µg/m³), dtype: object
