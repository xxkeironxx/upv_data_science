# %%
library("ggplot2")
data("diamonds")
##ggplot(diamonds, aes(carat, x*y*z)) + geom_point()
ggplot(diamonds, aes(log(price), log(carat))) + geom_point() 
#diamonds
# Out:
# plot without title

# %% [raw]
# read.csv
